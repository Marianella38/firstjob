# %% [markdown]
# # Data Sciencie Tools and Ecosystem

# %% [markdown]
# **In this notebook, Data Sciencie Tools and Ecosystem are summarized.**

# %% [markdown]
# **Objetives**

# %% [markdown]
# - Create a new Jupyter Notebook
# - Create a library list
# - Arimethic Expressions
# - Working with Jupyter Notebook
# - Popular languages for Data Sciencie
# - Data Sciencie Tools list

# %% [markdown]
# Some of the popular languages that Data Sciencie use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientist include:
#
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn

# %% [markdown]
# | Data Sciencie Tools |
# | ------------------- |
# | Jupyter IDE         |
# | R Studio            |
# | Spyder              |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# This a simple arimethic expression to multiply then add integers

# %%
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60.

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor
# Marianella Silva Peralta
